# %%
import pandas as pd
import numpy as np

# %%
EquityRev = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CompanyReviewCsvData/EquityReviews.csv")

# %%
# EDA on the data
def display(x):
    """This function returns a 
    summary of the dataset"""
    
    print("Displays the rows and columns in the dataset")
    print("============================================")
    Rows, col = x.shape
    print(f"Rows: {Rows} Columns: {col}")
    print()
    print("Displays data columns")
    print("============================================")
    print(x.columns)
    print()
    print("Returns the data information")
    print("============================================")
    print(x.info)
    print()
    print("Returns the information in more details")
    print("============================================")
    print(x.describe())
    print()
    print("The data type")
    print("============================================")
    print(x.dtypes)
    print()
    print("The number of null values in the dataset")
    print("============================================")
    print(x.isna().sum())
display(EquityRev)
# Out:
# Displays the rows and columns in the dataset
# ...
# Rows: 750 Columns: 6
#
# Displays data columns
# ...
# Index(['Job Title', 'Job Ratings', 'time', 'JobStatus', 'Pros', 'Cons'], dtype='object')
#
# Returns the data information
# ...
# <bound method DataFrame.info of                   Job Title  Job Ratings          time  \
# 0      Credit administrator          5.0  Jun 30, 2022
# 1          Sr. acct manager          1.0  Dec 20, 2024
# 2        Anonymous employee          4.0  Jul 28, 2023
# 3        Anonymous employee          4.0  Jan 26, 2016
# 4               Bank teller          2.0   Mar 1, 2021
# ..                      ...          ...           ...
# 745      Anonymous employee          1.0  Dec 27, 2015
# 746   Ban assurance officer          1.0  Oct 17, 2022
# 747          Credit officer          1.0  Sep 24, 2018
# 748    Relationship officer          1.0  Jun 17, 2022
# 749  Channel administrative          1.0   Oct 9, 2013
#
#                                JobStatus  \
# ...

# %%
# display the whole column content
pd.set_option("display.max_colwidth", None)

# %%
# The first 3 elements
print("Top 5 elements")
print("=============================")
print()
EquityRev.head()
# Out:
# Top 5 elements
# ...
#               Job Title  Job Ratings          time  \
# 0  Credit administrator          5.0  Jun 30, 2022
# 1      Sr. acct manager          1.0  Dec 20, 2024
# 2    Anonymous employee          4.0  Jul 28, 2023
# 3    Anonymous employee          4.0  Jan 26, 2016
# 4           Bank teller          2.0   Mar 1, 2021
#
#                             JobStatus  \
# 0  Former employee, more than 5 years
# 1  Former employee, more than 5 years
# 2                    Current employee
# 3                     Former employee
# 4   Former employee, more than 1 year
#
#                                                                                                                                                                                                                 Pros  \
# ...

# %%
# The last 3 elements
print("last 5 elements")
print("=============================")
print()
EquityRev.tail()
# Out:
# last 5 elements
# ...
#                   Job Title  Job Ratings          time  \
# 745      Anonymous employee          1.0  Dec 27, 2015
# 746   Ban assurance officer          1.0  Oct 17, 2022
# 747          Credit officer          1.0  Sep 24, 2018
# 748    Relationship officer          1.0  Jun 17, 2022
# 749  Channel administrative          1.0   Oct 9, 2013
#
#                                JobStatus  \
# 745   Current employee, more than 1 year
# 746    Former employee, more than 1 year
# 747  Current employee, more than 3 years
# 748   Former employee, more than 5 years
# 749   Former employee, more than 5 years
#
#                                                                     Pros  \
# 745                          great exposure and experience,robust sytems
# 746                Medical insurance cover. Low interest loans for staff
# 747  Robust systems, innovative, knowledgeable and energetic young staff
# ...

# %%
# The random 3 elements
print("Random 5 elements")
print("=============================")
print()
EquityRev.sample(5)
# Out:
# Random 5 elements
# ...
#                                         Job Title  Job Ratings          time  \
# 470  Senior communication and advertising officer          3.0   Feb 4, 2022
# 318                          Relationship manager          3.0   Apr 4, 2023
# 284                   Relationship officer credit          3.0   Sep 2, 2023
# 175                            Operations officer          3.0  Aug 30, 2024
# 83                            Security consultant          2.0   Jul 9, 2025
#
#                                JobStatus  \
# 470  Current employee, more than 3 years
# 318   Former employee, more than 8 years
# 284   Former employee, more than 5 years
# 175  Current employee, more than 3 years
# 83   Current employee, more than 8 years
#
#                                                                                                                                                           Pros  \
# ...

# %%
# loops over the whole column 1
for index,col in enumerate (EquityRev["Job Title"]):
    print(index, col)
# Out:
# 0 Credit administrator
# 1 Sr. acct manager
# 2 Anonymous employee
# 3 Anonymous employee
# 4 Bank teller
# 5 Relationship officer
# 6 Anonymous employee
# 7 Mortgage banker
# 8 R/o
# 9 Manager
# 10 Anonymous employee
# 11 Anonymous employee
# 12 Associate director
# 13 Commercial loan assistant
# 14 Anonymous employee
# 15 Teller
# 16 Banker
# 17 Administrative assistant
# 18 Anonymous employee
# 19 Anonymous employee
# 20 Anonymous employee
# 21 Anonymous employee
# 22 Associate director
# 23 Commercial loan assistant
# 24 Anonymous employee
# 25 Teller
# 26 Banker
# 27 Administrative assistant
# 28 Anonymous employee
# 29 Anonymous employee
# 30 Locked job title
# 31 Locked job title
# 32 Locked job title
# 33 Locked job title
# 34 Locked job title
# 35 Locked job title
# 36 Locked job title
# 37 Locked job title
# 38 Locked job title
# 39 Locked job title
# 40 Locked job title
# 41 Locked job title
# 42 Locked job title
# 43 Locked job title
# 44 Locked job title
# ...

# %%
EquityRev.iloc[30:49]
# Out:
#            Job Title  Job Ratings          time  \
# 30  Locked job title          5.0  Apr 25, 2025
# 31  Locked job title          5.0  Apr 25, 2025
# 32  Locked job title          5.0  Apr 25, 2025
# 33  Locked job title          5.0  Apr 25, 2025
# 34  Locked job title          5.0  Apr 25, 2025
# 35  Locked job title          5.0  Apr 25, 2025
# 36  Locked job title          5.0  Apr 25, 2025
# 37  Locked job title          5.0  Apr 25, 2025
# 38  Locked job title          5.0  Apr 25, 2025
# 39  Locked job title          5.0  Apr 25, 2025
# 40  Locked job title          5.0  Apr 25, 2025
# 41  Locked job title          5.0  Apr 25, 2025
# 42  Locked job title          5.0  Apr 25, 2025
# 43  Locked job title          5.0  Apr 25, 2025
# 44  Locked job title          5.0  Apr 25, 2025
# 45  Locked job title          5.0  Apr 25, 2025
# 46  Locked job title          5.0  Apr 25, 2025
# 47  Locked job title          5.0  Apr 25, 2025
# ...

# %%
# calculating total null values on the dataset
def null_values(df):
    """This function returns 
    total null values on the dataset"""
    print(df.isna().sum())
null_values(EquityRev)
# Out:
# Job Title       0
# Job Ratings     0
# time            0
# JobStatus       0
# Pros            0
# Cons           20
# dtype: int64

# %%
# dropping dublicate values
def duplicate_values(df):
    """This function drops all the 
    duplicate values on the dataset"""
    df.dropna(inplace=True)
duplicate_values(EquityRev)
# CisRev.dropna(inplace=True)

# %%
# changing the datatype of the time column
def time_change(df, col="time"):
    df[col] = pd.to_datetime(df[col], format='%b %d, %Y', errors="coerce")
    return df
Rev = time_change(EquityRev)

# %%
# Rename the headers
EquityRev.rename(columns={"Job Title":"Job Title", "Job Ratings":"Job Rating", "time":"Time", "JobStatus":"Job Status",
                      "Pros":"Pros","Cons":"Cons"},inplace=True)

# %%
# pd.set_option("display.Max_rows", None)
# pd.reset_option("display.Max_rows", None)

# %%
EquityRev
# Out:
#                   Job Title  Job Rating       Time  \
# 0      Credit administrator         5.0 2022-06-30
# 1          Sr. acct manager         1.0 2024-12-20
# 2        Anonymous employee         4.0 2023-07-28
# 3        Anonymous employee         4.0 2016-01-26
# 4               Bank teller         2.0 2021-03-01
# ..                      ...         ...        ...
# 745      Anonymous employee         1.0 2015-12-27
# 746   Ban assurance officer         1.0 2022-10-17
# 747          Credit officer         1.0 2018-09-24
# 748    Relationship officer         1.0 2022-06-17
# 749  Channel administrative         1.0 2013-10-09
#
#                               Job Status  \
# 0     Former employee, more than 5 years
# 1     Former employee, more than 5 years
# 2                       Current employee
# 3                        Former employee
# 4      Former employee, more than 1 year
# ..                                   ...
# 745   Current employee, more than 1 year
# ...

# %%
EquityRev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 730 entries, 0 to 749
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job Title   730 non-null    object
#  1   Job Rating  730 non-null    float64
#  2   Time        730 non-null    datetime64[ns]
#  3   Job Status  730 non-null    object
#  4   Pros        730 non-null    object
#  5   Cons        730 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 39.9+ KB

# %%
# SafRev["Pros"] = SafRev["Pros"].str.replace("\r", "", regex=False)
def remove_char(df, col="Pros", col2="Cons"):
    pattern = r"[\r\*\-\(\)]"
    df[["Pros", "Cons"]] = df[["Pros", "Cons"]].apply(
        lambda s: s.str.replace(pattern, "", regex=True))
    return df
remove_char(EquityRev)
# Out:
#                   Job Title  Job Rating       Time  \
# 0      Credit administrator         5.0 2022-06-30
# 1          Sr. acct manager         1.0 2024-12-20
# 2        Anonymous employee         4.0 2023-07-28
# 3        Anonymous employee         4.0 2016-01-26
# 4               Bank teller         2.0 2021-03-01
# ..                      ...         ...        ...
# 745      Anonymous employee         1.0 2015-12-27
# 746   Ban assurance officer         1.0 2022-10-17
# 747          Credit officer         1.0 2018-09-24
# 748    Relationship officer         1.0 2022-06-17
# 749  Channel administrative         1.0 2013-10-09
#
#                               Job Status  \
# 0     Former employee, more than 5 years
# 1     Former employee, more than 5 years
# 2                       Current employee
# 3                        Former employee
# 4      Former employee, more than 1 year
# ..                                   ...
# 745   Current employee, more than 1 year
# ...

# %%
# SafRev["Pros"] = SafRev["Pros"].str.replace("\r", "", regex=False)
def remove_char(df, col="Pros", col2="Cons"):
    df[["Pros", "Cons"]] = df[["Pros", "Cons"]].apply(
        lambda s: s.str.replace("\n", "", regex=True))
    return df
remove_char(EquityRev)
# Out:
#                   Job Title  Job Rating       Time  \
# 0      Credit administrator         5.0 2022-06-30
# 1          Sr. acct manager         1.0 2024-12-20
# 2        Anonymous employee         4.0 2023-07-28
# 3        Anonymous employee         4.0 2016-01-26
# 4               Bank teller         2.0 2021-03-01
# ..                      ...         ...        ...
# 745      Anonymous employee         1.0 2015-12-27
# 746   Ban assurance officer         1.0 2022-10-17
# 747          Credit officer         1.0 2018-09-24
# 748    Relationship officer         1.0 2022-06-17
# 749  Channel administrative         1.0 2013-10-09
#
#                               Job Status  \
# 0     Former employee, more than 5 years
# 1     Former employee, more than 5 years
# 2                       Current employee
# 3                        Former employee
# 4      Former employee, more than 1 year
# ..                                   ...
# 745   Current employee, more than 1 year
# ...

# %%
hiphen = EquityRev[EquityRev["Cons"].str.startswith("-")]
hiphen
# Out:
# Empty DataFrame
# Columns: [Job Title, Job Rating, Time, Job Status, Pros, Cons]
# Index: []

# %%
pd.set_option("display.max_rows",None)
# check duplicate
def checkDuplicate(df):
    df.duplicated()
    return df
checkDuplicate(EquityRev)
# Out:
#                                                        Job Title  Job Rating  \
# 0                                           Credit administrator         5.0
# 1                                               Sr. acct manager         1.0
# 2                                             Anonymous employee         4.0
# 3                                             Anonymous employee         4.0
# 4                                                    Bank teller         2.0
# 5                                           Relationship officer         4.0
# 6                                             Anonymous employee         5.0
# 7                                                Mortgage banker         4.0
# 8                                                            R/o         3.0
# 9                                                        Manager         5.0
# 10                                            Anonymous employee         3.0
# ...

# %%
# check duplicate sum
def checkDuplicateSum(df: pd.DataFrame) -> int:
    duplicate_count = df.duplicated().sum()
    return 'Sum of Duplicate_Values =', duplicate_count
checkDuplicateSum(EquityRev)
# Out:
# ('Sum of Duplicate_Values =', 20)

# %%
EquityRev.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60      True
# 61      True
# 62      True
# 63      True
# 64      True
# 65      True
# 66      True
# 67      True
# 68      True
# 69      True
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# ...

# %%
EquityRev.iloc[20:29]
# Out:
#                                                       Job Title  Job Rating  \
# 70                                     Senior software engineer         4.0
# 71                                               Credit officer         2.0
# 72                                         Relationship manager         1.0
# 74                                    Senior operations manager         3.0
# 75                              Digital banking project manager         5.0
# 76                                            Finance assistant         5.0
# 79                                      Relationship supervisor         3.0
# 81                                               Senior officer         1.0
# 82  Senior payment officer/project coordinator/business analyst         3.0
#
#          Time                            Job Status  \
# 70 2025-08-04    Current employee, less than 1 year
# 71 2025-08-05   Current employee, more than 5 years
# ...

# %%
def drop_duplicate(df: pd.DataFrame) -> int:
    """This function drops the duplicated 
        values in the dataset
    Args = df for the dataset
    return = this function returns a dataframe 
        withiout the duplicate values"""
    drop_duplicates = df.drop_duplicates(subset = ["Job Title"], inplace=True)
    return drop_duplicates
drop_duplicate(EquityRev)

# %%
Rows, columns = EquityRev.shape
print(f"Rows = {Rows}, columns = {columns}")
# Out:
# Rows = 268, columns = 6

# %%
EquityRev.reset_index(inplace=True)
# EquityRev.set_index("Job Title", inplace=True)
# Boltrev.drop("index", axis = 1, inplace=True)

# %%
EquityRev
# Out:
#                                                        Job Title  Job Rating  \
# 0                                           Credit administrator         5.0
# 1                                               Sr. acct manager         1.0
# 2                                             Anonymous employee         4.0
# 3                                                    Bank teller         2.0
# 4                                           Relationship officer         4.0
# 5                                                Mortgage banker         4.0
# 6                                                            R/o         3.0
# 7                                                        Manager         5.0
# 8                                             Associate director         4.0
# 9                                      Commercial loan assistant         4.0
# 10                                                        Teller         3.0
# ...

# %%
EquityRev.insert(6,"Company_Name", "Equity")

# %%
path = "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Equity.csv"

# %%
EquityRev.to_csv(path, index=False)

# %%
df = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Equity.csv")
df
# Out:
#                                                        Job Title  Job Rating  \
# 0                                           Credit administrator         5.0
# 1                                               Sr. acct manager         1.0
# 2                                             Anonymous employee         4.0
# 3                                                    Bank teller         2.0
# 4                                           Relationship officer         4.0
# 5                                                Mortgage banker         4.0
# 6                                                            R/o         3.0
# 7                                                        Manager         5.0
# 8                                             Associate director         4.0
# 9                                      Commercial loan assistant         4.0
# 10                                                        Teller         3.0
# ...
