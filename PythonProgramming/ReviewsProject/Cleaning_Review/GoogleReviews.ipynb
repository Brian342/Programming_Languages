# %% [markdown]
# <a href="https://colab.research.google.com/github/Brian342/JupyterAI-Clean/blob/main/GoogleReviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
GoogleRev = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CompanyReviewCsvData/googleReviews.csv")

# %%
# EDA on the data
def display(x):
    """This function returns a
    summary of the dataset"""

    print("Displays the rows and columns in the dataset")
    print("============================================")
    Rows, col = x.shape
    print(f"Rows: {Rows} Columns: {col}")
    print()
    print("Displays data columns")
    print("============================================")
    print(x.columns)
    print()
    print("Returns the data information")
    print("============================================")
    print(x.info)
    print()
    print("Returns the information in more details")
    print("============================================")
    print(x.describe())
    print()
    print("The data type")
    print("============================================")
    print(x.dtypes)
    print()
    print("The number of null values in the dataset")
    print("============================================")
    print(x.isna().sum())
display(GoogleRev)
# Out:
# Displays the rows and columns in the dataset
# ...
# Rows: 42430 Columns: 6
#
# Displays data columns
# ...
# Index(['Job Title', 'Job Ratings', 'time', 'JobStatus', 'Pros', 'Cons'], dtype='object')
#
# Returns the data information
# ...
# <bound method DataFrame.info of                                  Job Title  Job Ratings          time  \
# 0                          Program manager          4.0  Jun 21, 2013
# 1                    Software engineer iii          5.0  May 10, 2014
# 2                       Anonymous employee          5.0   Feb 8, 2015
# 3                          Program manager          4.0   Aug 5, 2025
# 4      Software development engineer (sde)          4.0  Jul 28, 2025
# ...                                    ...          ...           ...
# 42425                   Anonymous employee          5.0  Sep 27, 2022
# 42426                      Sales associate          5.0  Sep 28, 2022
# 42427                        Web developer          5.0  Sep 28, 2022
# ...

# %%
# display the whole text
pd.set_option("display.max_colwidth", None)

# %%
# printing the first 20 elements on the dataset
print("first 5 elements")
print("=====================================================")
print()
GoogleRev.head(5)
# Out:
# first 5 elements
# ...
#                              Job Title  Job Ratings          time  \
# 0                      Program manager          4.0  Jun 21, 2013
# 1                Software engineer iii          5.0  May 10, 2014
# 2                   Anonymous employee          5.0   Feb 8, 2015
# 3                      Program manager          4.0   Aug 5, 2025
# 4  Software development engineer (sde)          4.0  Jul 28, 2025
#
#                              JobStatus  \
# 0   Former employee, more than 8 years
# 1   Current employee, more than 1 year
# 2                     Current employee
# 3  Current employee, more than 3 years
# 4                      Former employee
#
# ...

# %%
# printing the last 5 elements on the dataset
print("first 5 elements")
print("=====================================================")
print()
GoogleRev.tail(5)
# Out:
# first 5 elements
# ...
#                   Job Title  Job Ratings          time  \
# 42425    Anonymous employee          5.0  Sep 27, 2022
# 42426       Sales associate          5.0  Sep 28, 2022
# 42427         Web developer          5.0  Sep 28, 2022
# 42428             Marketing          4.0  Sep 28, 2022
# 42429  Sales representative          4.0  Sep 28, 2022
#
#                                 JobStatus  \
# 42425                    Current employee
# 42426                    Current employee
# 42427  Current employee, more than 1 year
# 42428   Former employee, more than 1 year
# 42429                    Current employee
#
#                                                Pros  \
# 42425                     Great company to work for
# 42426  benefits benefits benefits benefits benefits
# 42427                  very good company to work in
# 42428        Amazing people and culture to work in.
# 42429   Cool environment. Good pay. Talented people
#
# ...

# %%
# printing the random 5 elements on the dataset
print("Random 5 elements")
print("=====================================================")
print()
GoogleRev.sample(5)
# Out:
# Random 5 elements
# ...
#                           Job Title  Job Ratings          time  \
# 25692        Senior account manager          5.0  Mar 17, 2022
# 20300  Associate account strategist          2.0  Oct 21, 2016
# 6290              Software engineer          5.0  Aug 24, 2024
# 34048               Program manager          4.0  Jul 28, 2022
# 1352                 Senior manager          5.0  May 22, 2025
#
#                                   JobStatus  \
# 25692   Current employee, more than 8 years
# 20300     Former employee, more than 1 year
# 6290     Current employee, less than 1 year
# 34048  Current employee, more than 10 years
# 1352                       Current employee
#
# ...

# %%
# checking the first column details
col1 = GoogleRev["Job Title"]
col1
# Out:
# 0                            Program manager
# 1                      Software engineer iii
# 2                         Anonymous employee
# 3                            Program manager
# 4        Software development engineer (sde)
#                         ...
# 42425                     Anonymous employee
# 42426                        Sales associate
# 42427                          Web developer
# 42428                              Marketing
# 42429                   Sales representative
# Name: Job Title, Length: 42430, dtype: object

# %%
# calculating total null values on the dataset
def null_values(df):
    """This function returns
    total null values on the dataset"""
    print(df.isna().sum())
null_values(GoogleRev)
# Out:
# Job Title      1
# Job Ratings    0
# time           0
# JobStatus      0
# Pros           0
# Cons           0
# dtype: int64

# %%
# dropping dublicate values
def duplicate_values(df):
    """This function drops all the
    duplicate values on the dataset"""
    df.dropna(inplace=True)
duplicate_values(GoogleRev)
# CisRev.dropna(inplace=True)

# %%
# changing the datatype of the time column
def time_change(df, col="time"):
    df[col] = pd.to_datetime(df[col], format='%b %d, %Y', errors="coerce")
    return df
Rev = time_change(GoogleRev)

# %%
# Rename the headers
GoogleRev.rename(columns={"Job Title":"Job Title", "Job Ratings":"Job Rating", "time":"Time", "JobStatus":"Job Status",
                      "Pros":"Pros","Cons":"Cons"},inplace=True)

# %%
# checking the unique values in the dataset
for job in GoogleRev["Job Title"].unique():
    print(job)
# Out:
# Program manager
# Software engineer iii
# Anonymous employee
# Software development engineer (sde)
# Account manager
# Software engineer
# Staff engineer
# Product manager
# Senior program manager
# Administrative
# Trading
# Engineer
# Software engineering manager
# People consultant
# Software engineer swe iii
# Applications engineer
# Software engineer apprentice
# Datacenter technician
# Software engineer (swe ii)
# Technical solutions engineer
# Senior software engineer
# Software developer
# Cloud engineer
# Dfm engineer
# Sde1 entry
# User experience designer
# Software engineer ii
# Technical recruiter
# Janitor
# Solutions engineer
# Ai cloud engineer
# Scaled operations manager
# Business analyst
# Senior manager
# Silicon design engineer
# Sofwatre engineer
# Data analyst
# Kak
# Senior ai engineer
# Software engineer l4
# Data scientist
# Sofware engineer ii
# Senior account strategist
# Senior creative lead
# Customer service representative (csr)
# Graphic designer
# ...

# %%
# capitalizing the dataset
def capital_letter(df, col="Job Title"):
    df[[col]] = df[[col]].apply(lambda c: c.str.title())
    return df
capital_letter(GoogleRev)
# Out:
#                                  Job Title  Job Rating       Time  \
# 0                          Program Manager         4.0 2013-06-21
# 1                    Software Engineer Iii         5.0 2014-05-10
# 2                       Anonymous Employee         5.0 2015-02-08
# 3                          Program Manager         4.0 2025-08-05
# 4      Software Development Engineer (Sde)         4.0 2025-07-28
# ...                                    ...         ...        ...
# 42425                   Anonymous Employee         5.0 2022-09-27
# 42426                      Sales Associate         5.0 2022-09-28
# 42427                        Web Developer         5.0 2022-09-28
# 42428                            Marketing         4.0 2022-09-28
# 42429                 Sales Representative         4.0 2022-09-28
#
#                                 Job Status  \
# 0       Former employee, more than 8 years
# 1       Current employee, more than 1 year
# ...

# %%
GoogleRev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42429 entries, 0 to 42429
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job Title   42429 non-null  object
#  1   Job Rating  42429 non-null  float64
#  2   Time        42429 non-null  datetime64[ns]
#  3   Job Status  42429 non-null  object
#  4   Pros        42429 non-null  object
#  5   Cons        42429 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.3+ MB

# %%
# rename detail
GoogleRev["Job Title"] = GoogleRev["Job Title"].replace({
    "Tdr Trade Development Representative":"(Tdr) Trade Development Representative",
    "Qaengineer":"Qa Engineer","Çustomer Service Representative":"Customer Service Representative",
    "Sofatware Engineer":"Software Engineer","Softeware Enginee":"Software Engineer",
    "Ftth Engineer":"Ftth (Fiber to the Home) Engineer","Software qa engineer":"Software Qa Engineer",
    "Tdr":"Trade Development Representative","Itspecialist":"IT Specialist",
    "KEY NOT FOUND: jobLine.seasonal-current":"(Job) seasonal_current","I T Analyst":"IT Analyst",
    "It Specialist":"IT Specialist"
    })

# %%
# SafRev["Pros"] = SafRev["Pros"].str.replace("\r", "", regex=False)
def remove_char(df, col="Pros", col2="Cons"):
    pattern = r"[\r\*\-\(\)]"
    df[["Pros", "Cons"]] = df[["Pros", "Cons"]].apply(
        lambda s: s.str.replace(pattern, "", regex=True))
    return df
remove_char(GoogleRev)
# Out:
#                                  Job Title  Job Rating       Time  \
# 0                          Program Manager         4.0 2013-06-21
# 1                    Software Engineer Iii         5.0 2014-05-10
# 2                       Anonymous Employee         5.0 2015-02-08
# 3                          Program Manager         4.0 2025-08-05
# 4      Software Development Engineer (Sde)         4.0 2025-07-28
# ...                                    ...         ...        ...
# 42425                   Anonymous Employee         5.0 2022-09-27
# 42426                      Sales Associate         5.0 2022-09-28
# 42427                        Web Developer         5.0 2022-09-28
# 42428                            Marketing         4.0 2022-09-28
# 42429                 Sales Representative         4.0 2022-09-28
#
#                                 Job Status  \
# 0       Former employee, more than 8 years
# 1       Current employee, more than 1 year
# ...

# %%
# SafRev["Pros"] = SafRev["Pros"].str.replace("\r", "", regex=False)
def remove_char(df, col="Pros", col2="Cons"):
    df[[col, col2]] = df[[col, col2]].apply(
        lambda s: s.str.replace("\n", " ", regex=False))
    return df
remove_char(GoogleRev)
# Out:
#                                  Job Title  Job Rating       Time  \
# 0                          Program Manager         4.0 2013-06-21
# 1                    Software Engineer Iii         5.0 2014-05-10
# 2                       Anonymous Employee         5.0 2015-02-08
# 3                          Program Manager         4.0 2025-08-05
# 4      Software Development Engineer (Sde)         4.0 2025-07-28
# ...                                    ...         ...        ...
# 42425                   Anonymous Employee         5.0 2022-09-27
# 42426                      Sales Associate         5.0 2022-09-28
# 42427                        Web Developer         5.0 2022-09-28
# 42428                            Marketing         4.0 2022-09-28
# 42429                 Sales Representative         4.0 2022-09-28
#
#                                 Job Status  \
# 0       Former employee, more than 8 years
# 1       Current employee, more than 1 year
# ...

# %%
hiphen = GoogleRev[GoogleRev["Pros"].str.startswith("-")]
hiphen
# Out:
# Empty DataFrame
# Columns: [Job Title, Job Rating, Time, Job Status, Pros, Cons]
# Index: []

# %%
# check duplicate
def checkDuplicate(df):
    df.duplicated()
    return df
checkDuplicate(GoogleRev)
# Out:
#                                  Job Title  Job Rating       Time  \
# 0                          Program Manager         4.0 2013-06-21
# 1                    Software Engineer Iii         5.0 2014-05-10
# 2                       Anonymous Employee         5.0 2015-02-08
# 3                          Program Manager         4.0 2025-08-05
# 4      Software Development Engineer (Sde)         4.0 2025-07-28
# ...                                    ...         ...        ...
# 42425                   Anonymous Employee         5.0 2022-09-27
# 42426                      Sales Associate         5.0 2022-09-28
# 42427                        Web Developer         5.0 2022-09-28
# 42428                            Marketing         4.0 2022-09-28
# 42429                 Sales Representative         4.0 2022-09-28
#
#                                 Job Status  \
# 0       Former employee, more than 8 years
# 1       Current employee, more than 1 year
# ...

# %%
# check duplicate sum
def checkDuplicateSum(df):
    Total = df.duplicated().sum()
    print(f"Sum of Duplicate_Values = {Total}")
checkDuplicateSum(GoogleRev)
# Out:
# Sum of Duplicate_Values = 81

# %%
# drop_duplicate
def DropDuplicate(df):
    df.drop_duplicates(subset=["Job Title"], inplace=True)
    return df
DropDuplicate(GoogleRev)
# Out:
#                                  Job Title  Job Rating       Time  \
# 0                          Program Manager         4.0 2013-06-21
# 1                    Software Engineer Iii         5.0 2014-05-10
# 2                       Anonymous Employee         5.0 2015-02-08
# 4      Software Development Engineer (Sde)         4.0 2025-07-28
# 5                          Account Manager         1.0 2025-07-08
# ...                                    ...         ...        ...
# 42335                        Boat Mechanic         5.0 2022-08-17
# 42365                        Cvg Marketing         4.0 2022-09-02
# 42379                              Actuary         5.0 2022-09-08
# 42384         Senior Information Developer         5.0 2022-09-11
# 42402                 Corporate Tax Intern         4.0 2022-09-19
#
#                                Job Status  \
# 0      Former employee, more than 8 years
# 1      Current employee, more than 1 year
# 2                        Current employee
# ...

# %%
GoogleRev[GoogleRev["Cons"].str.contains("\r")]
# Out:
# Empty DataFrame
# Columns: [Job Title, Job Rating, Time, Job Status, Pros, Cons]
# Index: []

# %%
GoogleRev.insert(6,"Company_Name", "Google")

# %%
GoogleRev.set_index("Job Title", inplace=True)

# %%
GoogleRev.reset_index(inplace=True)

# %%
GoogleRev
# Out:
#                                 Job Title  Job Rating       Time  \
# 0                         Program Manager         4.0 2013-06-21
# 1                   Software Engineer Iii         5.0 2014-05-10
# 2                      Anonymous Employee         5.0 2015-02-08
# 3     Software Development Engineer (Sde)         4.0 2025-07-28
# 4                         Account Manager         1.0 2025-07-08
# ...                                   ...         ...        ...
# 4909                        Boat Mechanic         5.0 2022-08-17
# 4910                        Cvg Marketing         4.0 2022-09-02
# 4911                              Actuary         5.0 2022-09-08
# 4912         Senior Information Developer         5.0 2022-09-11
# 4913                 Corporate Tax Intern         4.0 2022-09-19
#
#                               Job Status  \
# 0     Former employee, more than 8 years
# 1     Current employee, more than 1 year
# 2                       Current employee
# ...

# %%
Path  = "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Google.csv"

# %%
GoogleRev.to_csv(Path, index=False)
