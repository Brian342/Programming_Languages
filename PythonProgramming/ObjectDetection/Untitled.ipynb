# %%
# local datatest 
from ultralytics import YOLO
import cv2

# Load your model
model = YOLO('yolo26n.pt')

# This will open a window and show you the fire/smoke boxes in real-time
results = model.predict(source='0', show=True, conf=0.5)
