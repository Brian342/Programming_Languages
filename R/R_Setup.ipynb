# %%
file.create("Hello.R")
# Out:
# [1] TRUE

# %%
print("Hello, World")
# Out:
# [1] "Hello, World"

# %%
# getting user input
name <- readline("What's your name: ")
greeting <- paste("Hello,",name)
print(greeting)
# Out:
# What's your name:  james
# [1] "Hello, james"
